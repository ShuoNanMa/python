# %% [markdown]
# # 0402 可视化：“一图胜千言”
# Matplotlib是python中专门用于制作图形的标准库（mat就是math, plot画图，lib就是library 函数库），它的网站（http://matplotlib.org/） 上有各种图例和代码，想画什么图，你只需要下载并照着改改就可以了。另一个库是seaborn（http://seaborn.pydata.org/） ，它支持统计数据的可视化，我们下面讲统计库时用到会做一点简单介绍。此外，在前面的章节中有各种图形，大家可以自己去照着画。

# %% [markdown]
# ## 4.2.1 折线图

# %% [markdown]
# 给定平方数序列1,4,9,16,25，绘制折线图。注：x坐标默认是[0, 1, 2, 3, …]

# %%
import matplotlib.pyplot as plt
squares = [1,4,9,16,25]
plt.plot(squares) #折线图
plt.show()

# %% [markdown]
# 增加图中的标签元素：

# %%
import matplotlib.pyplot as plt
input_values = [1,2,3,4,5]
squares = [1,4,9,16,25]
plt.plot(input_values, squares, linewidth = 5) #折线图
# 设置图表标题，并给坐标轴加上标签
plt.title("Square Numbers", fontsize = 24)
plt.xlabel("Value", fontsize = 14)
plt.ylabel("Square of Value", fontsize = 14)

# 设置刻度标记的大小
plt.tick_params(axis='both', labelsize = 14)
plt.show()

# %% [markdown]
# 在图中画两条线，并注明图例（legend）:

# %%
import numpy as np
x = np.linspace(0, 2*np.pi, 50)
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend();

# %% [markdown]
# ## 4.2.2 散点图

# %%
import matplotlib.pyplot as plt
x_values = [1,2,3,4,5]#5个点的横坐标
y_values = [1,4,9,16,25] #5个点的纵坐标
plt.scatter(x_values,y_values, c = 'magenta', s = 200)#参数s指定点的大小，参数c指定点的颜色

plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize = 14)
plt.ylabel("Square of Value", fontsize = 14)

plt.tick_params(axis = 'both', which = 'major', labelsize = 14)
plt.show()

# %% [markdown]
# 颜色映射（colormap）是一系列颜色，它们从起始颜色渐变到
# 结束颜色。将参数c设置成了一个y值的列表，并使用参数cmap
# 说明使用哪个颜色映射（cm表示colormap，Blues表示一组蓝色）

# %%
import matplotlib.pyplot as plt
x_values = list(range(1, 1001))
y_values = [x**2 for x in x_values]
plt.scatter(x_values,y_values, edgecolor='none',
        c =y_values, cmap=plt.cm.Blues, s = 40)
plt.title("Square Numbers", fontsize=24)
plt.xlabel("Value", fontsize = 14)
plt.ylabel("Square of Value", fontsize = 14)
plt.tick_params(axis = 'both', which = 'major', labelsize = 14)
plt.axis([0, 1100, 0, 1100000])
plt.show()

# %% [markdown]
# ## 4.3 柱状图

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn
data = pd.read_csv('data/中国石油化工日交易数据2011-2019.csv')
close_prices = np.array(data['Clsprc'])
seaborn.set()  # 设置绘图风格，可help它的参数
plt.rcParams['font.sans-serif'] = ['KaiTi']#Pandas matplotlib 画图无法显示中文字体的问题, https://blog.csdn.net/lvshu_yuan/article/details/80413005
plt.rcParams['font.serif'] = ['KaiTi']
plt.hist(close_prices) #柱状图,横轴是close_prices的间隔，纵轴是频率
plt.title('中国石油化工（600028）2011-2019年日收盘价')
plt.xlabel('日收盘价 (元)')
plt.ylabel('频率（日）')
plt.savefig('中石化股价曲线.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 4.4  自动保存图片

# %% [markdown]
# 上例中：将plt.savefig('中石化股价曲线.png', bbox_inches='tight') 加在plt.show()之前。

# %% [markdown]
# ## 4.5 DataFrame的画图

# %%
from pandas_datareader import data
from datetime import datetime
GZMT = pd.read_csv('data/GZMT_data.csv')#index_col参数非常有用，它将'Date'这列设置为索引
GZMT['Date'] = pd.to_datetime(GZMT['Date'])#转换列的类型并保存
GZMT = GZMT.set_index(['Date'])#将index设置为Date并保存
GZMT.head()
GZMT_rolling = GZMT_close.rolling(365, center=True)#窗口大小为365，请help(GZMT_close.rolling)
print('type(GZMT_rolling):', type(GZMT_rolling))#查看类型
data = pd.DataFrame({'input': GZMT_close,
                     'one-year rolling_mean': GZMT_rolling.mean(),
                     'one-year rolling_std': GZMT_rolling.std()})
print('type(GZMT_rolling.mean()):', type(GZMT_rolling.mean()))#查看类型
ax = data.plot(style=['-', '--', ':'])
ax.lines[0].set_alpha(0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-363019cc3c02> in <module>()
#       6 GZMT = GZMT.set_index(['Date'])#将index设置为Date并保存
#       7 GZMT.head()
# ----> 8 GZMT_rolling = GZMT_close.rolling(365, center=True)#窗口大小为365，请help(GZMT_close.rolling)
#       9 print('type(GZMT_rolling):', type(GZMT_rolling))#查看类型
#      10 data = pd.DataFrame({'input': GZMT_close,
#
# NameError: name 'GZMT_close' is not defined
